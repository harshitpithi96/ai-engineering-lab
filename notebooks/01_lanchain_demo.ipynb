# %%
from transformers import pipeline

# %%
from langchain_community.llms import HuggingFacePipeline

# %%
pipe = pipeline("text-generation", model="Qwen/Qwen2.5-1.5B-Instruct", max_length = 512)
chat_model = HuggingFacePipeline(pipeline=pipe)
response = chat_model.invoke("what is langchain?")
# Out:
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer Qwen2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.

# %%
print(response)
# Out:
# what is langchain? I'm a python programmer, can you give me an example of how to use it in my code?
# LangChain is a Python library that provides a unified interface for interacting with different natural language processing (NLP) models. It abstracts away the complexities of working with various NLP libraries like spaCy, NLTK, or transformers, making it easier to build and deploy conversational AI applications.
#
# To get started with LangChain, you first need to install it using pip:
#
# ```bash
# pip install langchain
# ```
#
# Here's a simple example of how to use LangChain to interact with a pre-trained model such as Hugging Face's `transformers` library's BERT model:
#
# 1. **Install necessary packages:**
#    ```bash
#    pip install transformers torch
#    ```
#
# 2. **Import the required modules from LangChain:**
#
# ```python
# from langchain import LLMChain
# from langchain.chat_models import ChatOpenAI
# from langchain.prompts import PromptTemplate
#
# # Initialize the chat model
# llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)
# ```
#
# 3. **Define your prompt template:**
#
# ```python
# prompt_template = """
# You are a helpful assistant. Answer the user's question as helpfully as possible while remaining polite.
# User: {input}
# """
#
# # Create a prompt template instance
# prompt = PromptTemplate(input_variables=["input"], template=prompt_template)
# ```
#
# 4. **Create a chain:**
#
# ```python
# chain = LLMChain(llm=llm, prompt=prompt)
# ```
#
# 5. **Use the chain:**
#
# ```python
# response = chain.run("What is the capital of France?")
# print(response)
# ```
#
# This will output:
# ```
# Paris is the capital of France.
# ```
#
# ### Explanation:
# - **Prompt Template:** Defines the format of input data expected by the LLM.
# - **LLMChain:** A class that combines a Language Model Interface (LLM) with a prompt template to generate responses based on given inputs.
# - **ChatOpenAI:** An implementation of OpenAI’s GPT-3 family of large language models, designed specifically for text-based interactions.
#
# By following these steps, you can integrate LangChain into your project to leverage powerful NLP capabilities without needing to manage multiple libraries. This makes it particularly useful for building conversational interfaces where handling complex natural language understanding tasks is involved.
